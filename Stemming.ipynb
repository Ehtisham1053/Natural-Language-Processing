# %% [markdown]
# <a href="https://colab.research.google.com/github/Ehtisham1053/Natural-Language-Processing/blob/main/Stemming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #🔹 Stemming in NLP: A Complete Guide
# ##1️⃣ What is Stemming?
# Stemming is the process of reducing a word to its base/root form by removing prefixes and suffixes.
# * ✅ It is a rule-based technique that does not consider the meaning of words.
# * ✅ The resulting stem may not always be a valid word.

# %% [markdown]
# * Running ---->	Run
# * Studies ---->	Studi
# * Happily ---->	Happi
# *Played ---->	Play

# %% [markdown]
# ## 2️⃣ Why Use Stemming?
# Stemming is used to normalize words and reduce vocabulary size in NLP tasks such as:
#
# * Text Classification (Sentiment Analysis, Spam Detection)
# * Search Engines (Google, ElasticSearch, Lucene)
# * Information Retrieval (Finding similar words)
# * Topic Modeling (Grouping similar words)

# %% [markdown]
# ## 3️⃣ How Stemming Works?
# * Stemming removes suffixes and prefixes using predefined rules.
# * It does not use a dictionary, so sometimes the output might not be a valid word.

# %% [markdown]
# # 4️⃣ Types of Stemming Algorithms

# %% [markdown]
# ## 🔹 1. Porter Stemmer (Most Common)
# * ✅ Uses a set of rules to remove suffixes.
# * ✅ Fast but may produce non-dictionary words.

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()
words = ["running", "played", "studies", "happily"]
stems = [ps.stem(word) for word in words]
print(stems)
# Out:
# ['run', 'play', 'studi', 'happili']

# %% [markdown]
# ###🔹 Limitations:
#
# * "Studies" becomes "Studi" (not a valid word).
# * "Happily" becomes "Happili".

# %% [markdown]
# ## 🔹 2. Snowball Stemmer (Improved Porter Stemmer)
# * ✅ Works for multiple languages (English, French, German, etc.).
# * ✅ More accurate than Porter Stemmer.

# %%
from nltk.stem import SnowballStemmer

ss = SnowballStemmer("english")
words = ["running", "played", "studies", "happily"]
stems = [ss.stem(word) for word in words]
print(stems)
# Out:
# ['run', 'play', 'studi', 'happili']

# %% [markdown]
# ## 🔹 3. Lancaster Stemmer (Aggressive)
# * ✅ More aggressive than Porter.
# * ✅ Can over-stem words, making them too short.

# %%
from nltk.stem import LancasterStemmer

ls = LancasterStemmer()
words = ["running", "played", "studies", "happily"]
stems = [ls.stem(word) for word in words]
print(stems)
# Out:
# ['run', 'play', 'study', 'happy']

# %% [markdown]
# * 🔹 Pros: Works well for some words.
# * 🔹 Cons: Too aggressive ("happily" → "happy", "studies" → "study").

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##6️⃣ Challenges in Stemming
# * 🔸 Over-Stemming: Produces too short words.
# * 🔸 Under-Stemming: Fails to reduce similar words.
# * 🔸 Not Context-Aware: "Better" does not stem to "Good".
# * 🔸 Language-Specific: Each language requires custom rules.
