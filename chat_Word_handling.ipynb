# %% [markdown]
# <a href="https://colab.research.google.com/github/Ehtisham1053/Natural-Language-Processing/blob/main/chat_Word_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
abbreviation_dict = {
    "u": "you",
    "ur": "your",
    "r": "are",
    "y": "why",
    "bcoz": "because",
    "idk": "I don't know",
    "btw": "by the way",
    "brb": "be right back",
    "ttyl": "talk to you later",
    "omg": "oh my god",
    "lol": "laugh out loud",
    "rofl": "rolling on the floor laughing",
    "lmk": "let me know",
    "imo": "in my opinion",
    "imho": "in my humble opinion",
    "np": "no problem",
    "thx": "thanks",
    "ty": "thank you",
    "gg": "good game",
    "gl": "good luck",
    "hf": "have fun",
    "gr8": "great",
    "b4": "before",
    "afaik": "as far as I know",
    "fyi": "for your information",
    "tbh": "to be honest",
    "smh": "shaking my head",
    "w/e": "whatever",
    "w/o": "without",
    "idc": "I don’t care",
    "icymi": "in case you missed it",
    "ftw": "for the win",
    "jk": "just kidding",
    "irl": "in real life",
    "hbd": "happy birthday",
    "gm!": "good morning!",
    "gn": "good night",
    "cya": "see you",
    "asap": "as soon as possible",
    "dm": "direct message",
    "faq": "frequently asked questions",
    "nvm": "never mind"
}

# %% [markdown]
# ## Step 2: Function to Expand Abbreviations

# %%
import re

def expand_abbreviations(text, abbr_dict):
    """
    Expands abbreviations in a given text.

    Args:
    text (str): The input text.
    abbr_dict (dict): Dictionary of abbreviations.

    Returns:
    str: The expanded text.
    """
    words = text.split()  # Split text into words
    expanded_words = [abbr_dict.get(word.lower(), word) for word in words]  # Replace abbreviations
    return " ".join(expanded_words)  # Join words back into a sentence

# Example text
text = "gn bro! idk why u r not coming. btw, cya asap!"

# Expand abbreviations
expanded_text = expand_abbreviations(text, abbreviation_dict)

print("Original Text:", text)
print("Expanded Text:", expanded_text)
# Out:
# Original Text: gn bro! idk why u r not coming. btw, cya asap!
# Expanded Text: good night bro! I don't know why you are not coming. btw, see you asap!

# %% [markdown]
# ## Step 3: Expanding Abbreviations in a Dataset (Pandas)

# %%
import pandas as pd

data = {'Raw_Text': [
    "gm! how r u?",
    "idk why u r sad, ttyl!",
    "brb, need to go asap."
]}

df = pd.DataFrame(data)

# Apply function to clean dataset
df['Expanded_Text'] = df['Raw_Text'].apply(lambda x: expand_abbreviations(x, abbreviation_dict))

df
# Out:
#                  Raw_Text                        Expanded_Text
# 0            gm! how r u?              good morning how are u?
# 1  idk why u r sad, ttyl!  I don't know why you are sad, ttyl!
# 2   brb, need to go asap.                brb, need to go asap.
