# %% [markdown]
# <a href="https://colab.research.google.com/github/Ehtisham1053/Natural-Language-Processing/blob/main/Lemmatization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🔹 Lemmatization in NLP: A Complete Guide

# %% [markdown]
# ##1️⃣ What is Lemmatization?
# Lemmatization is the process of reducing a word to its base or dictionary form (lemma) while considering the word’s meaning and grammatical context.
#
# * ✅ Unlike stemming, lemmatization produces actual words.
# * ✅ Uses a dictionary lookup to get the correct base form.
# * ✅ Requires the part of speech (POS) tag for better accuracy.

# %% [markdown]
# ##2️⃣ Why Use Lemmatization?
# Lemmatization is more accurate than stemming because:
#
# * It considers the meaning and context of words.
# * It avoids incorrect word truncation (e.g., "studies" → "study", not "studi").
# * It ensures valid words for text processing in NLP applications.
# ##🔹 Applications
# * ✅ Search Engines → "Running" and "Run" should be treated as the same word.
# * ✅ Chatbots → Understanding sentence meaning.
# * ✅ Sentiment Analysis → "Better" should be recognized as "Good".
# * ✅ Machine Translation → Accurate language processing.

# %% [markdown]
# ##3️⃣ How Lemmatization Works?
# Lemmatization requires two things:
# * 🔹 The word itself
# * 🔹 The correct Part of Speech (POS) tag
#
# Without a POS tag, words may not be lemmatized correctly.
# * 🔹 "Running" → "Run" (verb)
# * 🔹 "Better" → "Good" (adjective)

# %% [markdown]
# #4️⃣ Implementing Lemmatization in Python
# ##🔹 Using WordNet Lemmatizer (NLTK)

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

words = ["running", "played", "better", "studies", "happily"]

lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Without POS Tag: ['running', 'played', 'better', 'study', 'happily']

# %%
print("Without POS Tag:", lemmatized_words)
# Out:
# Without POS Tag: ['running', 'played', 'better', 'study', 'happily']

# %% [markdown]
# ## 🔹 Lemmatization with POS Tags
# To improve accuracy, we must specify the correct POS tag.

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger_eng')

lemmatizer = WordNetLemmatizer()

words = ["running", "played", "better", "studies", "happily"]

lemmatized_words1 = [lemmatizer.lemmatize(word) for word in words]


# Function to get correct POS tag
def get_wordnet_pos(word):
    from nltk.corpus import wordnet
    from nltk import pos_tag
    tag = pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ, "N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)  # Default to noun

# Lemmatization with POS tags
lemmatized_words = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in words]
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %%
print("original words" , words)
print("Without POS Tag:", lemmatized_words1)
print("With POS Tag:", lemmatized_words)
# Out:
# original words ['running', 'played', 'better', 'studies', 'happily']
# Without POS Tag: ['running', 'played', 'better', 'study', 'happily']
# With POS Tag: ['run', 'played', 'well', 'study', 'happily']

# %% [markdown]
# ![image.png](data:image/png;base64,...)
